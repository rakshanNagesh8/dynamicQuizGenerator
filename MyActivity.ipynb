# %%
# 1. Import OpenAl and configure api-key in a new Jupyter Notebook instance.
# 2. Craft a simple prompt for GPT-3 instructing it to generate a short story set in a period of your choosing.
# 3. Utilize the 'openai.Completion.create' method to send this prompt to GPT-3 and retrieve a response.
# 4. Enhance your original prompt by incorporating more detailed instructions and context, and then leverage GPT-3 to generate
# 5. another response.
# 6. You should have two responses generated by GPT-3 which demonstrate the effect of your prompt refinement.

import openai
import os

os.environ['API_KEY'] = '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'
openai.api_key = os.getenv('API_KEY')

print('\nThis is your Key: ' + openai.api_key)
# Out:
# This is your Key: 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

# %%
basic_prompt = 'Write a fictional short story set in the British Raj of India'

# %%
response = openai.Completion.create(
    engine = 'text-davinci-003',
    prompt = basic_prompt,
    max_tokens=256
)

print(response['choices'][0]['text'])
# Out:
# The wind howled across the Raj, blasting dust and sand through the air and blurring the vision of those below. Through out the countryside, villagers huddled against the oppressive onslaught, praying for respite.
#
# In one of the villages, a young boy of fourteen was stood at the centre of the village, ready to set off on a journey he had been told he would take since birth. He had been given a map and told to go to a far off land and report back on what he found there.
#
# He had been given nothing else - no money, no protection, no weapons - and was entirely on his own for this perilous expedition. The heat was intense and the dust stifled his every breath as he trudged through the countryside.
#
# ...

# %%
instructions = 'Write a fictional story about an Indian Assassin set in the British Raj of India'
details = ' The story should start with a very strong anticipation, show the assassin as one of the most skilled and feared assassins,
+ 'and show his motives to be helping the country gain independence faster'
second_details = ' The story should have a twist in between which cannot be anticipated, and it should end on a cliffhanger'
basic_prompt = instructions + details + second_details

# %%
response = openai.Completion.create(
    engine = 'text-davinci-003',
    prompt = basic_prompt,
    max_tokens=2000
)

print(response['choices'][0]['text'])
# Out:
# He was known to be the most skilled and feared assassin in British Raj of India, a man that moved without sound, spoke without a trace, and killed with great precision; the Indian Assassin.
#
# No one had seen his face since his emergence in the 1800s, but his work was swift and effective. Stories of him sprung up in various regions of India and gradually spread fear even among the British. People believed him to be an embodiment of justice on behalf of the native population, however, no one could guess his real motive - an end to British Raj.
#
# It had been a year since his last mission - in disguise of a British drifter - where he had assassinated the oppressive governor of a small town in the northern border of India. News of the governor’s death had sent shockwaves among the higher judiciary and triggered chaos among the public who had always been oppressed by the regime.
#
# ...
